# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame

# %%
top10 = [59.014444,69.670000,28.175556,30.151111,64.991111,37.935185,15.824074,33.564815,54.772222] 
eleven_25 = [60.345000, 67.684286, 27.655000,26.939286,61.532143,38.386905,18.160714,33.619048,48.402857]
twenty6_50 = [61.703684,68.733684,28.860000,27.306842,61.113684,38.197368,16.938596,34.548246,51.117895]
fifty1_100=[58.315667,67.146667,27.810333,30.519000,62.840000,38.250000,17.941667,34.358333,51.857111]
over100=[58.682273,67.357273,29.058182,31.394545,58.907273,37.729167,17.308712,33.926136,51.061364]

x=[0,1,2,3,4,5,6,7,8]
labels=['Driving Accuracy %','GIR %','Putts Per Round','Rough Tendency','Scrambling','Proximity to Hole','Approaches under 100 yards','Approaches over 100 yards','Sand Save %']

results1 = DataFrame({'Top 10':top10, '11-25':eleven_25, '26-50':twenty6_50,'51-100':fifty1_100,'Over 100':over100})
results1.plot()

plt.xticks(x,labels, rotation='vertical')
plt.legend(loc='lower left')
plt.ylabel('Yards or Percentage')

plt.savefig('GolfChart.png',bbox_inches='tight',dpi=200)
